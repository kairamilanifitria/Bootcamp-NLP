# %% [markdown]
# <a href="https://colab.research.google.com/github/kairamilanifitria/Bootcamp-NLP/blob/main/Project%202%20Text%20Summarization/Project2_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# Load the dataset
train_df = pd.read_csv('/content/drive/MyDrive/Bootcamp AI/Dataset/Task2 : Text Summarization/train.csv')
test_df = pd.read_csv('/content/drive/MyDrive/Bootcamp AI/Dataset/Task2 : Text Summarization/test.csv')
dev_df = pd.read_csv('/content/drive/MyDrive/Bootcamp AI/Dataset/Task2 : Text Summarization/dev.csv')

# %%
train_df.head()
# Out:
#        id  \
# 0  238168
# 1  205215
# 2  146657
# 3  123694
# 4  139266
#
#                                                                                      url  \
# 0  https://www.liputan6.com/news/read/238168/haykal-dan-putri-titian-siap-jadi-mahasiswa
# 1                         https://www.liputan6.com/news/read/205215/defoe-tetap-di-spurs
# 2   https://www.liputan6.com/news/read/146657/ramadan-menjelang--harga-sembako-menjulang
# 3       https://www.liputan6.com/news/read/123694/evakuasi-wni-dari-timor-leste-berakhir
# 4                   https://www.liputan6.com/news/read/139266/gunung-batutara-siaga-tiga
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           clean_article  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [['Liputan6', '.', 'com', ',', 'Jakarta', ':', 'Setelah', 'menjalani', 'Ujian', 'Nasional', ',', 'artis', 'muda', 'Haykal', 'Kamil', 'bersiap', 'kuliah', '.'], ['Adik', 'dari', 'Zaskia', 'Adya', 'Mecca', 'itu', 'mengaku', 'dirinya', 'sengaja', 'absen', 'dari', 'layar', 'kaca', 'beberapa', 'waktu', 'silam', 'demi', 'pendidikan', '.'], ['"', 'Sengaja', 'syuting-syuting', 'aku', 'pending', '(', 'tunda', ')', 'semuanya', 'selama', 'kurang', 'kurang', 'lebih', 'empat', 'bulanan', ',', '"', 'ucap', 'Haykal', 'kepada', 'tim', 'Kasak', 'Kusuk', 'SCTV', ',', 'Kamis', '(', '23/7', ')', '.'], ['Ia', 'ingin', 'mengambil', 'jurusan', 'Hubungan', 'Internasional', 'atau', 'Ilmu', 'Politik', 'di', 'Universitas', 'Indonesia', '.'], ['Senada', 'dengan', 'Haykal', ',', 'Putri', 'Titian', 'pun', 'akan', 'memasuki', 'dunia', 'baru', ',', 'perkuliahan', '.'], ['Perempuan', 'bernama', 'lengkap', 'Putri', 'Titian', 'Asih', 'itu', 'mengungkapkan', 'sempat', 'bingung', 'menentukan', 'jurusan', 'yang', 'akan', 'diambilnya', 'nanti', '.'], ['Namun', ',', 'setelah', 'dipikir', 'masak-masak', ',', 'Tiansapaan', 'akrab', 'Putri', 'Titianmemutuskan', 'mengambil', 'Desain', 'Komunikasi', 'Visual', 'di', 'Universitas', 'Trisakti', '.'], ['Tian', 'sempat', 'mengalami', 'dilema', '.'], ['Ia', 'mendapat', 'tekanan', 'dari', 'keluarga', 'untuk', 'mengubah', 'penampilannya', 'yang', 'tomboi', '.'], ['Namun', 'demi', 'menjaga', 'sikap', 'di', 'bangku', 'kuliah', ',', 'pemain', 'sinetron', 'Gara-Gara', 'Cinta', 'itu', 'rela', 'melakukannya', '.'], ['"', 'Mulai', 'sekarang', 'biasain', 'pakai', 'yang', 'formil-formil', 'aja', ',', 'yang', 'lebih', 'rapi', ',', '"', 'ucap', 'Tian', '.', '(', 'ANS', ')', '.']]
# 1  [['Striker', 'Timnas', 'Inggris', 'yang', 'bermain', 'bersama', 'Tottenham', 'Hotspur', ',', 'Jermain', 'Defoe', 'disebut-sebut', 'sebagai', 'salah', 'satu', 'talenta', 'terbaik', 'yang', 'pernah', 'dimiliki', 'The', 'Three', 'Lions', '.'], ['Meski', 'demikian', ',', 'Defoe', 'gagal', 'mendapat', 'kepercayaan', 'dari', 'Sven-Goran', 'Eriksson', 'untuk', 'masuk', 'dalam', 'skuad', 'inti', 'sat', 'berlaga', 'di', 'PD', '2006', 'lalu', '.', 'Bergabung', 'bersama', 'Spurs', ',', 'di', 'penghujung', 'musim', '2003-04', ',', 'Defoe', 'tampil', 'gemilang', ',', 'mencetak', 'tujuh', '(', '7', ')', 'gol', 'dari', '14', 'pertandingan', '.'], ['Di', 'musim', '2004-05', ',', 'penyerang', 'kelahiran', 'London', 'itu', 'berhasil', 'mencetak', '13', 'gol', 'dari', '28', 'partai', 'premiership', 'dan', 'sembilan', '(', '9', ')', 'gol', 'dalam', 'tujuh', 'pertandingan', 'di', 'dua', 'kompetisi', ',', 'FA', 'Cup', 'dan', 'Carling', 'Cup', '.'], ['Total', 'dari', '86', 'penampilan', 'Defoe', 'sebagai', 'starter', 'bersama', 'Spurs', ',', 'ia', 'mampu', 'mencetak', '47', 'gol', '.'], ['Itulah', 'yang', 'membuat', 'Defoe', 'laris', 'dispekulasikan', 'menjadi', '“', 'barang', 'dagangan', '”', 'di', 'bursa', 'transfer', '.'], ['Apalagi', ',', 'dengan', 'datangnya', 'Dimitar', 'Berbatov', 'dan', 'Ahmed', 'Mido', 'Hossam', ',', 'nasib', 'Defoe', 'kian', 'hangat', 'diperbincangkan', '.'], ['Maklumlah', ',', 'manajer', 'Martin', 'Jol', 'kerap', 'membangkucadangkan', 'Defoe', '.'], ['Namun', ',', 'kondisi', 'mulai', 'berubah', 'ketika', 'Defoe', 'tampil', 'ciamik', ',', 'mencetak', 'delapan', 'gol', 'dalam', 'tujuh', 'pertandingan', 'terakhir', ',', 'termasuk', 'saat', 'Defoe', 'memborong', 'dua', 'gol', 'bagi', 'kemenangan', 'Spurs', 'atas', 'Dinamo', 'Bucharest', 'di', 'ajang', 'UEFA', 'Cup', ',', 'Kamis', 'lalu', '.'], ['Defoe', 'pun', 'semakin', 'yakin', 'keputusannya', 'untuk', 'tetap', 'di', 'White', 'Hart', 'Lane', 'adalah', 'pilihan', 'jitu', '.'], ['“', 'Saya', 'sangat', 'senang', 'bergabung', 'bersama', 'Spurs', '.'], ['Saya', 'kira', 'publik', 'pun', 'tahu', 'benar', 'bahwa', 'saya', 'senang', 'bermain', 'di', 'sini', ',', '”', 'kata', 'Defoe', 'seperti', 'yang', 'dikutip', 'The', 'Times', '.'], ['Ketika', 'ditanya', 'tentang', 'spekulasi', 'ia', 'bakal', 'direkrut', 'tim-tim', 'besar', 'di', 'bursa', 'transfer', 'Januari', '2007', ',', 'Defoe', 'balik', 'menjawab', '.'], ['“', 'Jika', 'saya', 'mampu', 'tampil', 'baik', 'di', 'sini', ',', 'mengapa', 'saya', 'punya', 'keinginan', 'untuk', 'pergi', 'ke', 'tim', 'lain', '?'], ['Itu', 'tidak', 'masuk', 'akal', '.'], ['Saya', 'yakin', 'saya', 'mampu', 'berprestasi', 'di', 'sini', '.'], ['Skuad', 'Spurs', 'saat', 'ini', 'sangatlah', 'kuat', ',', 'banyak', 'pemain', 'berkualitas', '.'], ['Saya', 'senang', 'bermain', 'dengan', 'mereka', ',', 'dan', 'itulah', 'yang', 'akan', 'saya', 'lakukan', ',', '”', 'tandas', 'Defoe', '.', 'Awalnya', ',', 'Jol', 'cukup', 'pusing', 'dengan', 'kualitas', 'empat', 'strikernya', 'yang', 'hampir', 'sama', 'rata', ',', 'Defoe', ',', 'Berbatov', ',', 'Keane', ',', 'dan', 'Mido', '.'], ['Namun', ',', 'seiring', 'dengan', 'cederanya', 'Keane', 'dan', 'Mido', ',', 'justru', 'itu', 'merupakan', '"', 'berkah', '"', 'tersendiri', 'bagi', 'Jol', ',', 'dan', 'terutama', 'Defoe', '.'], ['Meski', 'demikian', ',', 'Defoe', 'tak', 'ingin', 'dirinya', 'disebut', 'mendapat', '“', 'kesempatan', 'dalam', 'kesempitan', '”', '.'], ['“', 'Seluruh', 'skuad', 'sangat', 'berharap', 'mereka', 'yang', 'cedera', 'dapat', 'sembuh', 'kembali', ',', 'baik', 'Robbie', '(', 'Keane', ')', ',', 'Mido', ',', 'maupun', 'JJ', '(', 'Jermaine', 'Jenas', ')', '.'], ['Sebab', ',', 'saya', 'pun', 'tidak', 'akan', 'mampu', 'tampil', 'baik', 'dalam', 'setiap', 'pertandingan', '.'], ['Inilah', 'guna', 'dan', 'arti', 'penting', 'sebuah', 'tim', ',', 'yang', 'mana', 'pemainnya', 'mampu', 'saling', 'berkontribusi', 'untuk', 'membantu', 'tim', 'memenangkan', 'pertandingan', ',', '”', 'kata', 'Defoe', '.']]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [['Liputan6', '.', 'com', ',', 'Jakarta', ':', 'Harga', 'sejumlah', 'kebutuhan', 'pokok', 'di', 'berbagai', 'daerah', 'mengalami', 'kenaikan', 'dalam', 'sepekan', 'terakhir', '.'], ['Di', 'Pasar', 'Mampang', 'dan', 'Pasar', 'Tebet', ',', 'Jakarta', 'Selatan', ',', 'misalnya', ',', 'hanya', 'komoditas', 'beras', 'yang', 'tidak', 'mengalami', 'kenaikan', '.'], ['Sedangkan', 'minyak', 'goreng', 'dan', 'telur', 'mengalami', 'kenaikan', 'yang', 'paling', 'tinggi', 'dalam', 'dua', 'hari', 'ini', ',', 'yaitu', 'mencapai', 'Rp', '2', '.', '000', 'per', 'kilogram', '.'], ['Kebutuhan', 'pokok', 'lainnya', 'seperti', 'gula', ',', 'susu', ',', 'dan', 'sayur-sayuran', 'mengalami', 'kenaikan', 'Rp', '500', 'per', 'kilogramnya', '.'], ['Sementara', 'di', 'Kota', 'Ambon', ',', 'Maluku', ',', 'harga', 'minyak', 'goreng', 'di', 'sejumlah', 'pasar', 'tradisional', 'dalam', 'tiga', 'hari', 'terakhir', 'merangkak', 'naik', 'mencapai', 'Rp', '3', '.', '000', 'per', 'kilogram', '.'], ['Kini', ',', 'warga', 'harus', 'membeli', 'satu', 'kilogram', 'minyak', 'goreng', 'seharga', 'Rp', '12', 'ribu', '.'], ['Menurut', 'para', 'pedagang', ',', 'kenaikan', 'harga', 'disebabkan', 'langkanya', 'pasokan', 'minyak', 'goreng', 'ke', 'wilayah', 'Ambon', '.'], ['Sedangkan', 'di', 'Majene', ',', 'Sulawesi', 'Barat', ',', 'menjelang', 'Ramadan', 'ini', 'harga', 'sembako', 'di', 'pasar', 'tradisional', 'juga', 'melonjak', 'naik', '.'], ['Lonjakan', 'harga', 'paling', 'tinggi', 'terjadi', 'pada', 'terigu', 'ukuran', '25', 'kilogram', 'yang', 'naik', 'Rp', '13', 'ribu', 'setiap', 'karung', '.'], ['Kenaikan', 'juga', 'terjadi', 'pada', 'harga', 'telur', 'yang', 'mencapai', 'Rp', '150', 'untuk', 'satu', 'butir', '.'], ['Daerah', 'lain', 'yang', 'juga', 'mengalami', 'kenaikan', 'sejumlah', 'bahan', 'pokok', 'adalah', 'Karawang', ',', 'Jabar', ',', 'dan', 'Serang', ',', 'Banten', '.'], ['Diperkirakan', ',', 'lonjakan', 'harga', 'akan', 'terus', 'terjadi', 'hingga', 'menjelang', 'Lebaran', 'mendatang', '[', 'baca', ':', 'Harga-Harga', 'Terus', 'Merangkak', 'Naik', ']', '.', '(', 'ADO/Tim', 'Liputan', '6', 'SCTV', ')', '.']]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [['Liputan6', ',', 'com', ',', 'Kupang', ':', 'Evakuasi', 'warga', 'negara', 'Indonesia', 'dari', 'Timor', 'Leste', 'dengan', 'dua', 'Hercules', 'TNI', 'Angkatan', 'Udara', 'berakhir', ',', 'Selasa', '(', '30/5', ')', '.'], ['Dalam', 'empat', 'hari', 'ini', ',', '1', '.', '540', 'WNI', 'telah', 'diangkut', 'keluar', 'dari', 'Timor', 'Leste', 'melalui', 'udara', '.'], ['Sekitar', 'lima', 'ratus', 'WNI', 'meninggalkan', 'Dili', 'lewat', 'jalur', 'darat', '.', 'Dari', 'kurang', 'lebih', '3', '.', '000', 'orang', ',', 'masih', 'tersisa', 'sekitar', '1', '.', '000', 'warga', 'Indonesia', 'yang', 'belum', 'dievakuasi', '.'], ['Sebagian', 'dari', 'mereka', 'masih', 'berharap', 'kondisi', 'keamanan', 'Timor', 'Leste', 'segera', 'pulih', '[', 'baca', ':', 'WNI', 'Keluar', 'Dili', 'Dalam', 'Kondisi', 'Stres', ']', '.'], ['Sebagian', 'lain', 'tidak', 'diketahui', 'keberadaannya', 'hingga', 'sulit', 'dievakuasi', '.'], ['TNI', 'AU', 'masih', 'menyiagakan', 'dua', 'pesawat', 'Hercules', 'di', 'Kupang', ',', 'Nusatenggara', 'Timur', ',', 'untuk', 'mengangkut', 'WNI', 'yang', 'tersisa', '.'], ['Suasana', 'Kota', 'Dili', 'masih', 'mencekam', '.'], ['Penjarahan', 'dan', 'pembakaran', 'rumah', 'terjadi', 'di', 'berbagai', 'sudut', 'kota', '.'], ['Pertentangan', 'antara', 'kelompok', 'warga', 'yang', 'dari', 'wilayah', 'barat', 'atau', 'Loromanu', 'dengan', 'warga', 'dari', 'wilayah', 'timur', 'atau', 'Lorosae', 'makin', 'runcing', '.'], ['Sebagian', 'pasukan', 'pemerintah', 'Timor', 'Leste', 'yang', 'berasal', 'dari', 'wilayah', 'bagian', 'timur', 'turut', 'memperkeruh', 'suasana', '.'], ['Pasukan', 'yang', 'masih', 'setia', 'terhadap', 'pemerintah', 'ini', 'mengintimidasi', 'warga', 'Dili', 'yang', 'berasal', 'dari', 'wilayah', 'barat', '.'], ['Kondisi', 'panas', 'ini', 'memicu', 'perbedaan', 'pendapat', 'antara', 'Presiden', 'Xanana', 'Gusmao', 'dan', 'Perdana', 'Menteri', 'Mari', 'Alkatiri', '.'], ['Gusmao', 'menginginkan', 'pelucutan', 'senjata', 'seluruh', 'polisi', 'dan', 'militer', 'dan', 'mempekerjakan', 'sekitar', '600', 'tentara', 'desertir', 'yang', 'memberontak', '.'], ['Sedangkan', 'Alkatiri', 'menghendaki', 'pelucutan', 'senjata', 'bagi', 'pasukan', 'pemberontak', 'saja', 'sebelum', 'kembali', 'bertugas', '.', '(', 'TNA/Tim', 'Liputan', '6', 'SCTV', ')', '.']]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [['Liputan6', '.', 'com', ',', 'Lembata', ':', 'Pusat', 'Vulkanologi', 'dan', 'Mitigasi', 'Bencana', 'Geologi', 'Bandung', 'menetapkan', 'status', 'Gunung', 'Batutara', 'di', 'Kabupaten', 'Lembata', ',', 'Nusatenggara', 'Timur', 'menjadi', 'siaga', 'tiga', ',', 'karena', 'lahar', 'panas', 'terus', 'keluar', 'dari', 'puncak', 'gunung', ',', 'sejak', '19', 'Maret', 'silam', '.'], ['Lahar', 'panas', 'juga', 'keluar', 'dari', 'bagian', 'sebelah', 'timur', 'kaki', 'Gunung', 'Batutara', '.'], ['Lahar', 'tersebut', 'mengalir', 'ke', 'laut', '.', 'Gunung', 'Batutara', 'yang', 'tingginya', 'sekitar', '3', '.', '700', 'meter', 'dari', 'permukaan', 'laut', 'terletak', 'di', 'Pulau', 'Komba', 'yang', 'tak', 'berpenghuni', '.'], ['Meski', 'begitu', ',', 'warga', 'empat', 'kecamatan', 'yang', 'menghuni', 'sebuah', 'pulau', 'sekitar', '50', 'kilometer', 'dari', 'Pulau', 'Komba', 'diminta', 'waspada', '.'], ['Adapun', 'jarak', 'pusat', 'kota', 'Lembata', ',', 'Leholba', 'dari', 'Gunung', 'Batutara', 'sekitar', '100', 'kilometer', '.', '(', 'JUM/Tim', 'Liputan', '6', 'SCTV', ')', '.']]
#
#                                                                                                                                                                                                                                                                                                                             clean_summary  \
# 0                                                                   [['Artis', 'muda', 'Haykal', 'dan', 'Putri', 'Titan', 'akan', 'memasuki', 'dunia', 'perkuliahan', '.'], ['Walau', 'hasil', 'ujian', 'belum', 'keluar', ',', 'Haykal', 'dan', 'Tian', 'mengaku', 'sudah', 'memiliki', 'universitas', 'favorit', 'masing-masing', '.']]
# 1  [['Pertandingan', 'melawan', 'Manchester', 'City', 'merupakan', 'partai', 'ke-120', 'Jermain', 'Defoe', 'bersama', 'Tottenham', 'Hotspur', '.'], ['Meski', 'mendapat', 'lirikan', 'dari', 'Manchester', 'United', 'dan', 'Aston', 'Villa', ',', 'Defoe', 'bertekad', 'tetap', 'akan', 'merumput', 'di', 'White', 'Hart', 'Lane', '.']]
# 2                                 [['Harga', 'bahan', 'pokok', 'seperti', 'minyak', 'goreng', ',', 'telur', ',', 'dan', 'terigu', 'di', 'beberapa', 'daerah', 'melonjak', 'naik', 'sejak', 'sepekan', 'terakhir', '.'], ['Kenaikan', 'tersebut', 'diperkirakan', 'terus', 'terjadi', 'hingga', 'menjelang', 'Lebaran', 'mendatang', '.']]
# 3          [['Evakuasi', 'warga', 'negara', 'Indonesia', 'dari', 'Timor', 'Leste', 'berakhir', 'hari', 'ini', '.'], ['Sebanyak', '1', '.', '500', 'lebih', 'warga', 'dievakuasi', 'lewat', 'udara', ',', '500', 'orang', 'keluar', 'dari', 'Dili', 'lewat', 'jalur', 'darat', ',', 'dan', 'seribu', 'orang', 'memilih', 'bertahan', '.']]
# 4                                                      [['Status', 'Gunung', 'Batutara', 'ditetapkan', 'siaga', 'tiga', 'karena', 'lahar', 'panas', 'terus', 'mengalir', 'dari', 'puncaknya', 'sejak', 'pekan', 'silam', '.'], ['Warga', 'yang', 'tinggal', 'sekitar', '50', 'kilometer', 'dari', 'Batutara', 'diminta', 'waspada', '.']]
#
#   extractive_summary
# 0             [0, 4]
# 1             [0, 8]
# 2            [0, 11]
# 3             [1, 2]
# 4             [1, 3]

# %%
#! pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
import string

def preprocess_text(text):
  text = text.lower()
  return text

train_df['text'] = train_df['clean_article'].apply(preprocess_text)
train_df['summary'] = train_df['clean_summary'].apply(preprocess_text)

test_df['text'] = test_df['clean_article'].apply(preprocess_text)
test_df['summary'] = test_df['clean_summary'].apply(preprocess_text)

dev_df['text'] = dev_df['clean_article'].apply(preprocess_text)
dev_df['summary'] = dev_df['clean_summary'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
train_df.head()
# Out:
#        id  \
# 0  238168
# 1  205215
# 2  146657
# 3  123694
# 4  139266
#
#                                                                                      url  \
# 0  https://www.liputan6.com/news/read/238168/haykal-dan-putri-titian-siap-jadi-mahasiswa
# 1                         https://www.liputan6.com/news/read/205215/defoe-tetap-di-spurs
# 2   https://www.liputan6.com/news/read/146657/ramadan-menjelang--harga-sembako-menjulang
# 3       https://www.liputan6.com/news/read/123694/evakuasi-wni-dari-timor-leste-berakhir
# 4                   https://www.liputan6.com/news/read/139266/gunung-batutara-siaga-tiga
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           clean_article  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [['Liputan6', '.', 'com', ',', 'Jakarta', ':', 'Setelah', 'menjalani', 'Ujian', 'Nasional', ',', 'artis', 'muda', 'Haykal', 'Kamil', 'bersiap', 'kuliah', '.'], ['Adik', 'dari', 'Zaskia', 'Adya', 'Mecca', 'itu', 'mengaku', 'dirinya', 'sengaja', 'absen', 'dari', 'layar', 'kaca', 'beberapa', 'waktu', 'silam', 'demi', 'pendidikan', '.'], ['"', 'Sengaja', 'syuting-syuting', 'aku', 'pending', '(', 'tunda', ')', 'semuanya', 'selama', 'kurang', 'kurang', 'lebih', 'empat', 'bulanan', ',', '"', 'ucap', 'Haykal', 'kepada', 'tim', 'Kasak', 'Kusuk', 'SCTV', ',', 'Kamis', '(', '23/7', ')', '.'], ['Ia', 'ingin', 'mengambil', 'jurusan', 'Hubungan', 'Internasional', 'atau', 'Ilmu', 'Politik', 'di', 'Universitas', 'Indonesia', '.'], ['Senada', 'dengan', 'Haykal', ',', 'Putri', 'Titian', 'pun', 'akan', 'memasuki', 'dunia', 'baru', ',', 'perkuliahan', '.'], ['Perempuan', 'bernama', 'lengkap', 'Putri', 'Titian', 'Asih', 'itu', 'mengungkapkan', 'sempat', 'bingung', 'menentukan', 'jurusan', 'yang', 'akan', 'diambilnya', 'nanti', '.'], ['Namun', ',', 'setelah', 'dipikir', 'masak-masak', ',', 'Tiansapaan', 'akrab', 'Putri', 'Titianmemutuskan', 'mengambil', 'Desain', 'Komunikasi', 'Visual', 'di', 'Universitas', 'Trisakti', '.'], ['Tian', 'sempat', 'mengalami', 'dilema', '.'], ['Ia', 'mendapat', 'tekanan', 'dari', 'keluarga', 'untuk', 'mengubah', 'penampilannya', 'yang', 'tomboi', '.'], ['Namun', 'demi', 'menjaga', 'sikap', 'di', 'bangku', 'kuliah', ',', 'pemain', 'sinetron', 'Gara-Gara', 'Cinta', 'itu', 'rela', 'melakukannya', '.'], ['"', 'Mulai', 'sekarang', 'biasain', 'pakai', 'yang', 'formil-formil', 'aja', ',', 'yang', 'lebih', 'rapi', ',', '"', 'ucap', 'Tian', '.', '(', 'ANS', ')', '.']]
# 1  [['Striker', 'Timnas', 'Inggris', 'yang', 'bermain', 'bersama', 'Tottenham', 'Hotspur', ',', 'Jermain', 'Defoe', 'disebut-sebut', 'sebagai', 'salah', 'satu', 'talenta', 'terbaik', 'yang', 'pernah', 'dimiliki', 'The', 'Three', 'Lions', '.'], ['Meski', 'demikian', ',', 'Defoe', 'gagal', 'mendapat', 'kepercayaan', 'dari', 'Sven-Goran', 'Eriksson', 'untuk', 'masuk', 'dalam', 'skuad', 'inti', 'sat', 'berlaga', 'di', 'PD', '2006', 'lalu', '.', 'Bergabung', 'bersama', 'Spurs', ',', 'di', 'penghujung', 'musim', '2003-04', ',', 'Defoe', 'tampil', 'gemilang', ',', 'mencetak', 'tujuh', '(', '7', ')', 'gol', 'dari', '14', 'pertandingan', '.'], ['Di', 'musim', '2004-05', ',', 'penyerang', 'kelahiran', 'London', 'itu', 'berhasil', 'mencetak', '13', 'gol', 'dari', '28', 'partai', 'premiership', 'dan', 'sembilan', '(', '9', ')', 'gol', 'dalam', 'tujuh', 'pertandingan', 'di', 'dua', 'kompetisi', ',', 'FA', 'Cup', 'dan', 'Carling', 'Cup', '.'], ['Total', 'dari', '86', 'penampilan', 'Defoe', 'sebagai', 'starter', 'bersama', 'Spurs', ',', 'ia', 'mampu', 'mencetak', '47', 'gol', '.'], ['Itulah', 'yang', 'membuat', 'Defoe', 'laris', 'dispekulasikan', 'menjadi', '“', 'barang', 'dagangan', '”', 'di', 'bursa', 'transfer', '.'], ['Apalagi', ',', 'dengan', 'datangnya', 'Dimitar', 'Berbatov', 'dan', 'Ahmed', 'Mido', 'Hossam', ',', 'nasib', 'Defoe', 'kian', 'hangat', 'diperbincangkan', '.'], ['Maklumlah', ',', 'manajer', 'Martin', 'Jol', 'kerap', 'membangkucadangkan', 'Defoe', '.'], ['Namun', ',', 'kondisi', 'mulai', 'berubah', 'ketika', 'Defoe', 'tampil', 'ciamik', ',', 'mencetak', 'delapan', 'gol', 'dalam', 'tujuh', 'pertandingan', 'terakhir', ',', 'termasuk', 'saat', 'Defoe', 'memborong', 'dua', 'gol', 'bagi', 'kemenangan', 'Spurs', 'atas', 'Dinamo', 'Bucharest', 'di', 'ajang', 'UEFA', 'Cup', ',', 'Kamis', 'lalu', '.'], ['Defoe', 'pun', 'semakin', 'yakin', 'keputusannya', 'untuk', 'tetap', 'di', 'White', 'Hart', 'Lane', 'adalah', 'pilihan', 'jitu', '.'], ['“', 'Saya', 'sangat', 'senang', 'bergabung', 'bersama', 'Spurs', '.'], ['Saya', 'kira', 'publik', 'pun', 'tahu', 'benar', 'bahwa', 'saya', 'senang', 'bermain', 'di', 'sini', ',', '”', 'kata', 'Defoe', 'seperti', 'yang', 'dikutip', 'The', 'Times', '.'], ['Ketika', 'ditanya', 'tentang', 'spekulasi', 'ia', 'bakal', 'direkrut', 'tim-tim', 'besar', 'di', 'bursa', 'transfer', 'Januari', '2007', ',', 'Defoe', 'balik', 'menjawab', '.'], ['“', 'Jika', 'saya', 'mampu', 'tampil', 'baik', 'di', 'sini', ',', 'mengapa', 'saya', 'punya', 'keinginan', 'untuk', 'pergi', 'ke', 'tim', 'lain', '?'], ['Itu', 'tidak', 'masuk', 'akal', '.'], ['Saya', 'yakin', 'saya', 'mampu', 'berprestasi', 'di', 'sini', '.'], ['Skuad', 'Spurs', 'saat', 'ini', 'sangatlah', 'kuat', ',', 'banyak', 'pemain', 'berkualitas', '.'], ['Saya', 'senang', 'bermain', 'dengan', 'mereka', ',', 'dan', 'itulah', 'yang', 'akan', 'saya', 'lakukan', ',', '”', 'tandas', 'Defoe', '.', 'Awalnya', ',', 'Jol', 'cukup', 'pusing', 'dengan', 'kualitas', 'empat', 'strikernya', 'yang', 'hampir', 'sama', 'rata', ',', 'Defoe', ',', 'Berbatov', ',', 'Keane', ',', 'dan', 'Mido', '.'], ['Namun', ',', 'seiring', 'dengan', 'cederanya', 'Keane', 'dan', 'Mido', ',', 'justru', 'itu', 'merupakan', '"', 'berkah', '"', 'tersendiri', 'bagi', 'Jol', ',', 'dan', 'terutama', 'Defoe', '.'], ['Meski', 'demikian', ',', 'Defoe', 'tak', 'ingin', 'dirinya', 'disebut', 'mendapat', '“', 'kesempatan', 'dalam', 'kesempitan', '”', '.'], ['“', 'Seluruh', 'skuad', 'sangat', 'berharap', 'mereka', 'yang', 'cedera', 'dapat', 'sembuh', 'kembali', ',', 'baik', 'Robbie', '(', 'Keane', ')', ',', 'Mido', ',', 'maupun', 'JJ', '(', 'Jermaine', 'Jenas', ')', '.'], ['Sebab', ',', 'saya', 'pun', 'tidak', 'akan', 'mampu', 'tampil', 'baik', 'dalam', 'setiap', 'pertandingan', '.'], ['Inilah', 'guna', 'dan', 'arti', 'penting', 'sebuah', 'tim', ',', 'yang', 'mana', 'pemainnya', 'mampu', 'saling', 'berkontribusi', 'untuk', 'membantu', 'tim', 'memenangkan', 'pertandingan', ',', '”', 'kata', 'Defoe', '.']]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [['Liputan6', '.', 'com', ',', 'Jakarta', ':', 'Harga', 'sejumlah', 'kebutuhan', 'pokok', 'di', 'berbagai', 'daerah', 'mengalami', 'kenaikan', 'dalam', 'sepekan', 'terakhir', '.'], ['Di', 'Pasar', 'Mampang', 'dan', 'Pasar', 'Tebet', ',', 'Jakarta', 'Selatan', ',', 'misalnya', ',', 'hanya', 'komoditas', 'beras', 'yang', 'tidak', 'mengalami', 'kenaikan', '.'], ['Sedangkan', 'minyak', 'goreng', 'dan', 'telur', 'mengalami', 'kenaikan', 'yang', 'paling', 'tinggi', 'dalam', 'dua', 'hari', 'ini', ',', 'yaitu', 'mencapai', 'Rp', '2', '.', '000', 'per', 'kilogram', '.'], ['Kebutuhan', 'pokok', 'lainnya', 'seperti', 'gula', ',', 'susu', ',', 'dan', 'sayur-sayuran', 'mengalami', 'kenaikan', 'Rp', '500', 'per', 'kilogramnya', '.'], ['Sementara', 'di', 'Kota', 'Ambon', ',', 'Maluku', ',', 'harga', 'minyak', 'goreng', 'di', 'sejumlah', 'pasar', 'tradisional', 'dalam', 'tiga', 'hari', 'terakhir', 'merangkak', 'naik', 'mencapai', 'Rp', '3', '.', '000', 'per', 'kilogram', '.'], ['Kini', ',', 'warga', 'harus', 'membeli', 'satu', 'kilogram', 'minyak', 'goreng', 'seharga', 'Rp', '12', 'ribu', '.'], ['Menurut', 'para', 'pedagang', ',', 'kenaikan', 'harga', 'disebabkan', 'langkanya', 'pasokan', 'minyak', 'goreng', 'ke', 'wilayah', 'Ambon', '.'], ['Sedangkan', 'di', 'Majene', ',', 'Sulawesi', 'Barat', ',', 'menjelang', 'Ramadan', 'ini', 'harga', 'sembako', 'di', 'pasar', 'tradisional', 'juga', 'melonjak', 'naik', '.'], ['Lonjakan', 'harga', 'paling', 'tinggi', 'terjadi', 'pada', 'terigu', 'ukuran', '25', 'kilogram', 'yang', 'naik', 'Rp', '13', 'ribu', 'setiap', 'karung', '.'], ['Kenaikan', 'juga', 'terjadi', 'pada', 'harga', 'telur', 'yang', 'mencapai', 'Rp', '150', 'untuk', 'satu', 'butir', '.'], ['Daerah', 'lain', 'yang', 'juga', 'mengalami', 'kenaikan', 'sejumlah', 'bahan', 'pokok', 'adalah', 'Karawang', ',', 'Jabar', ',', 'dan', 'Serang', ',', 'Banten', '.'], ['Diperkirakan', ',', 'lonjakan', 'harga', 'akan', 'terus', 'terjadi', 'hingga', 'menjelang', 'Lebaran', 'mendatang', '[', 'baca', ':', 'Harga-Harga', 'Terus', 'Merangkak', 'Naik', ']', '.', '(', 'ADO/Tim', 'Liputan', '6', 'SCTV', ')', '.']]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [['Liputan6', ',', 'com', ',', 'Kupang', ':', 'Evakuasi', 'warga', 'negara', 'Indonesia', 'dari', 'Timor', 'Leste', 'dengan', 'dua', 'Hercules', 'TNI', 'Angkatan', 'Udara', 'berakhir', ',', 'Selasa', '(', '30/5', ')', '.'], ['Dalam', 'empat', 'hari', 'ini', ',', '1', '.', '540', 'WNI', 'telah', 'diangkut', 'keluar', 'dari', 'Timor', 'Leste', 'melalui', 'udara', '.'], ['Sekitar', 'lima', 'ratus', 'WNI', 'meninggalkan', 'Dili', 'lewat', 'jalur', 'darat', '.', 'Dari', 'kurang', 'lebih', '3', '.', '000', 'orang', ',', 'masih', 'tersisa', 'sekitar', '1', '.', '000', 'warga', 'Indonesia', 'yang', 'belum', 'dievakuasi', '.'], ['Sebagian', 'dari', 'mereka', 'masih', 'berharap', 'kondisi', 'keamanan', 'Timor', 'Leste', 'segera', 'pulih', '[', 'baca', ':', 'WNI', 'Keluar', 'Dili', 'Dalam', 'Kondisi', 'Stres', ']', '.'], ['Sebagian', 'lain', 'tidak', 'diketahui', 'keberadaannya', 'hingga', 'sulit', 'dievakuasi', '.'], ['TNI', 'AU', 'masih', 'menyiagakan', 'dua', 'pesawat', 'Hercules', 'di', 'Kupang', ',', 'Nusatenggara', 'Timur', ',', 'untuk', 'mengangkut', 'WNI', 'yang', 'tersisa', '.'], ['Suasana', 'Kota', 'Dili', 'masih', 'mencekam', '.'], ['Penjarahan', 'dan', 'pembakaran', 'rumah', 'terjadi', 'di', 'berbagai', 'sudut', 'kota', '.'], ['Pertentangan', 'antara', 'kelompok', 'warga', 'yang', 'dari', 'wilayah', 'barat', 'atau', 'Loromanu', 'dengan', 'warga', 'dari', 'wilayah', 'timur', 'atau', 'Lorosae', 'makin', 'runcing', '.'], ['Sebagian', 'pasukan', 'pemerintah', 'Timor', 'Leste', 'yang', 'berasal', 'dari', 'wilayah', 'bagian', 'timur', 'turut', 'memperkeruh', 'suasana', '.'], ['Pasukan', 'yang', 'masih', 'setia', 'terhadap', 'pemerintah', 'ini', 'mengintimidasi', 'warga', 'Dili', 'yang', 'berasal', 'dari', 'wilayah', 'barat', '.'], ['Kondisi', 'panas', 'ini', 'memicu', 'perbedaan', 'pendapat', 'antara', 'Presiden', 'Xanana', 'Gusmao', 'dan', 'Perdana', 'Menteri', 'Mari', 'Alkatiri', '.'], ['Gusmao', 'menginginkan', 'pelucutan', 'senjata', 'seluruh', 'polisi', 'dan', 'militer', 'dan', 'mempekerjakan', 'sekitar', '600', 'tentara', 'desertir', 'yang', 'memberontak', '.'], ['Sedangkan', 'Alkatiri', 'menghendaki', 'pelucutan', 'senjata', 'bagi', 'pasukan', 'pemberontak', 'saja', 'sebelum', 'kembali', 'bertugas', '.', '(', 'TNA/Tim', 'Liputan', '6', 'SCTV', ')', '.']]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [['Liputan6', '.', 'com', ',', 'Lembata', ':', 'Pusat', 'Vulkanologi', 'dan', 'Mitigasi', 'Bencana', 'Geologi', 'Bandung', 'menetapkan', 'status', 'Gunung', 'Batutara', 'di', 'Kabupaten', 'Lembata', ',', 'Nusatenggara', 'Timur', 'menjadi', 'siaga', 'tiga', ',', 'karena', 'lahar', 'panas', 'terus', 'keluar', 'dari', 'puncak', 'gunung', ',', 'sejak', '19', 'Maret', 'silam', '.'], ['Lahar', 'panas', 'juga', 'keluar', 'dari', 'bagian', 'sebelah', 'timur', 'kaki', 'Gunung', 'Batutara', '.'], ['Lahar', 'tersebut', 'mengalir', 'ke', 'laut', '.', 'Gunung', 'Batutara', 'yang', 'tingginya', 'sekitar', '3', '.', '700', 'meter', 'dari', 'permukaan', 'laut', 'terletak', 'di', 'Pulau', 'Komba', 'yang', 'tak', 'berpenghuni', '.'], ['Meski', 'begitu', ',', 'warga', 'empat', 'kecamatan', 'yang', 'menghuni', 'sebuah', 'pulau', 'sekitar', '50', 'kilometer', 'dari', 'Pulau', 'Komba', 'diminta', 'waspada', '.'], ['Adapun', 'jarak', 'pusat', 'kota', 'Lembata', ',', 'Leholba', 'dari', 'Gunung', 'Batutara', 'sekitar', '100', 'kilometer', '.', '(', 'JUM/Tim', 'Liputan', '6', 'SCTV', ')', '.']]
#
#                                                                                                                                                                                                                                                                                                                             clean_summary  \
# 0                                                                   [['Artis', 'muda', 'Haykal', 'dan', 'Putri', 'Titan', 'akan', 'memasuki', 'dunia', 'perkuliahan', '.'], ['Walau', 'hasil', 'ujian', 'belum', 'keluar', ',', 'Haykal', 'dan', 'Tian', 'mengaku', 'sudah', 'memiliki', 'universitas', 'favorit', 'masing-masing', '.']]
# 1  [['Pertandingan', 'melawan', 'Manchester', 'City', 'merupakan', 'partai', 'ke-120', 'Jermain', 'Defoe', 'bersama', 'Tottenham', 'Hotspur', '.'], ['Meski', 'mendapat', 'lirikan', 'dari', 'Manchester', 'United', 'dan', 'Aston', 'Villa', ',', 'Defoe', 'bertekad', 'tetap', 'akan', 'merumput', 'di', 'White', 'Hart', 'Lane', '.']]
# 2                                 [['Harga', 'bahan', 'pokok', 'seperti', 'minyak', 'goreng', ',', 'telur', ',', 'dan', 'terigu', 'di', 'beberapa', 'daerah', 'melonjak', 'naik', 'sejak', 'sepekan', 'terakhir', '.'], ['Kenaikan', 'tersebut', 'diperkirakan', 'terus', 'terjadi', 'hingga', 'menjelang', 'Lebaran', 'mendatang', '.']]
# 3          [['Evakuasi', 'warga', 'negara', 'Indonesia', 'dari', 'Timor', 'Leste', 'berakhir', 'hari', 'ini', '.'], ['Sebanyak', '1', '.', '500', 'lebih', 'warga', 'dievakuasi', 'lewat', 'udara', ',', '500', 'orang', 'keluar', 'dari', 'Dili', 'lewat', 'jalur', 'darat', ',', 'dan', 'seribu', 'orang', 'memilih', 'bertahan', '.']]
# 4                                                      [['Status', 'Gunung', 'Batutara', 'ditetapkan', 'siaga', 'tiga', 'karena', 'lahar', 'panas', 'terus', 'mengalir', 'dari', 'puncaknya', 'sejak', 'pekan', 'silam', '.'], ['Warga', 'yang', 'tinggal', 'sekitar', '50', 'kilometer', 'dari', 'Batutara', 'diminta', 'waspada', '.']]
#
#   extractive_summary  \
# 0             [0, 4]
# 1             [0, 8]
# 2            [0, 11]
# 3             [1, 2]
# 4             [1, 3]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [['liputan6', '.', 'com', ',', 'jakarta', ':', 'setelah', 'menjalani', 'ujian', 'nasional', ',', 'artis', 'muda', 'haykal', 'kamil', 'bersiap', 'kuliah', '.'], ['adik', 'dari', 'zaskia', 'adya', 'mecca', 'itu', 'mengaku', 'dirinya', 'sengaja', 'absen', 'dari', 'layar', 'kaca', 'beberapa', 'waktu', 'silam', 'demi', 'pendidikan', '.'], ['"', 'sengaja', 'syuting-syuting', 'aku', 'pending', '(', 'tunda', ')', 'semuanya', 'selama', 'kurang', 'kurang', 'lebih', 'empat', 'bulanan', ',', '"', 'ucap', 'haykal', 'kepada', 'tim', 'kasak', 'kusuk', 'sctv', ',', 'kamis', '(', '23/7', ')', '.'], ['ia', 'ingin', 'mengambil', 'jurusan', 'hubungan', 'internasional', 'atau', 'ilmu', 'politik', 'di', 'universitas', 'indonesia', '.'], ['senada', 'dengan', 'haykal', ',', 'putri', 'titian', 'pun', 'akan', 'memasuki', 'dunia', 'baru', ',', 'perkuliahan', '.'], ['perempuan', 'bernama', 'lengkap', 'putri', 'titian', 'asih', 'itu', 'mengungkapkan', 'sempat', 'bingung', 'menentukan', 'jurusan', 'yang', 'akan', 'diambilnya', 'nanti', '.'], ['namun', ',', 'setelah', 'dipikir', 'masak-masak', ',', 'tiansapaan', 'akrab', 'putri', 'titianmemutuskan', 'mengambil', 'desain', 'komunikasi', 'visual', 'di', 'universitas', 'trisakti', '.'], ['tian', 'sempat', 'mengalami', 'dilema', '.'], ['ia', 'mendapat', 'tekanan', 'dari', 'keluarga', 'untuk', 'mengubah', 'penampilannya', 'yang', 'tomboi', '.'], ['namun', 'demi', 'menjaga', 'sikap', 'di', 'bangku', 'kuliah', ',', 'pemain', 'sinetron', 'gara-gara', 'cinta', 'itu', 'rela', 'melakukannya', '.'], ['"', 'mulai', 'sekarang', 'biasain', 'pakai', 'yang', 'formil-formil', 'aja', ',', 'yang', 'lebih', 'rapi', ',', '"', 'ucap', 'tian', '.', '(', 'ans', ')', '.']]
# 1  [['striker', 'timnas', 'inggris', 'yang', 'bermain', 'bersama', 'tottenham', 'hotspur', ',', 'jermain', 'defoe', 'disebut-sebut', 'sebagai', 'salah', 'satu', 'talenta', 'terbaik', 'yang', 'pernah', 'dimiliki', 'the', 'three', 'lions', '.'], ['meski', 'demikian', ',', 'defoe', 'gagal', 'mendapat', 'kepercayaan', 'dari', 'sven-goran', 'eriksson', 'untuk', 'masuk', 'dalam', 'skuad', 'inti', 'sat', 'berlaga', 'di', 'pd', '2006', 'lalu', '.', 'bergabung', 'bersama', 'spurs', ',', 'di', 'penghujung', 'musim', '2003-04', ',', 'defoe', 'tampil', 'gemilang', ',', 'mencetak', 'tujuh', '(', '7', ')', 'gol', 'dari', '14', 'pertandingan', '.'], ['di', 'musim', '2004-05', ',', 'penyerang', 'kelahiran', 'london', 'itu', 'berhasil', 'mencetak', '13', 'gol', 'dari', '28', 'partai', 'premiership', 'dan', 'sembilan', '(', '9', ')', 'gol', 'dalam', 'tujuh', 'pertandingan', 'di', 'dua', 'kompetisi', ',', 'fa', 'cup', 'dan', 'carling', 'cup', '.'], ['total', 'dari', '86', 'penampilan', 'defoe', 'sebagai', 'starter', 'bersama', 'spurs', ',', 'ia', 'mampu', 'mencetak', '47', 'gol', '.'], ['itulah', 'yang', 'membuat', 'defoe', 'laris', 'dispekulasikan', 'menjadi', '“', 'barang', 'dagangan', '”', 'di', 'bursa', 'transfer', '.'], ['apalagi', ',', 'dengan', 'datangnya', 'dimitar', 'berbatov', 'dan', 'ahmed', 'mido', 'hossam', ',', 'nasib', 'defoe', 'kian', 'hangat', 'diperbincangkan', '.'], ['maklumlah', ',', 'manajer', 'martin', 'jol', 'kerap', 'membangkucadangkan', 'defoe', '.'], ['namun', ',', 'kondisi', 'mulai', 'berubah', 'ketika', 'defoe', 'tampil', 'ciamik', ',', 'mencetak', 'delapan', 'gol', 'dalam', 'tujuh', 'pertandingan', 'terakhir', ',', 'termasuk', 'saat', 'defoe', 'memborong', 'dua', 'gol', 'bagi', 'kemenangan', 'spurs', 'atas', 'dinamo', 'bucharest', 'di', 'ajang', 'uefa', 'cup', ',', 'kamis', 'lalu', '.'], ['defoe', 'pun', 'semakin', 'yakin', 'keputusannya', 'untuk', 'tetap', 'di', 'white', 'hart', 'lane', 'adalah', 'pilihan', 'jitu', '.'], ['“', 'saya', 'sangat', 'senang', 'bergabung', 'bersama', 'spurs', '.'], ['saya', 'kira', 'publik', 'pun', 'tahu', 'benar', 'bahwa', 'saya', 'senang', 'bermain', 'di', 'sini', ',', '”', 'kata', 'defoe', 'seperti', 'yang', 'dikutip', 'the', 'times', '.'], ['ketika', 'ditanya', 'tentang', 'spekulasi', 'ia', 'bakal', 'direkrut', 'tim-tim', 'besar', 'di', 'bursa', 'transfer', 'januari', '2007', ',', 'defoe', 'balik', 'menjawab', '.'], ['“', 'jika', 'saya', 'mampu', 'tampil', 'baik', 'di', 'sini', ',', 'mengapa', 'saya', 'punya', 'keinginan', 'untuk', 'pergi', 'ke', 'tim', 'lain', '?'], ['itu', 'tidak', 'masuk', 'akal', '.'], ['saya', 'yakin', 'saya', 'mampu', 'berprestasi', 'di', 'sini', '.'], ['skuad', 'spurs', 'saat', 'ini', 'sangatlah', 'kuat', ',', 'banyak', 'pemain', 'berkualitas', '.'], ['saya', 'senang', 'bermain', 'dengan', 'mereka', ',', 'dan', 'itulah', 'yang', 'akan', 'saya', 'lakukan', ',', '”', 'tandas', 'defoe', '.', 'awalnya', ',', 'jol', 'cukup', 'pusing', 'dengan', 'kualitas', 'empat', 'strikernya', 'yang', 'hampir', 'sama', 'rata', ',', 'defoe', ',', 'berbatov', ',', 'keane', ',', 'dan', 'mido', '.'], ['namun', ',', 'seiring', 'dengan', 'cederanya', 'keane', 'dan', 'mido', ',', 'justru', 'itu', 'merupakan', '"', 'berkah', '"', 'tersendiri', 'bagi', 'jol', ',', 'dan', 'terutama', 'defoe', '.'], ['meski', 'demikian', ',', 'defoe', 'tak', 'ingin', 'dirinya', 'disebut', 'mendapat', '“', 'kesempatan', 'dalam', 'kesempitan', '”', '.'], ['“', 'seluruh', 'skuad', 'sangat', 'berharap', 'mereka', 'yang', 'cedera', 'dapat', 'sembuh', 'kembali', ',', 'baik', 'robbie', '(', 'keane', ')', ',', 'mido', ',', 'maupun', 'jj', '(', 'jermaine', 'jenas', ')', '.'], ['sebab', ',', 'saya', 'pun', 'tidak', 'akan', 'mampu', 'tampil', 'baik', 'dalam', 'setiap', 'pertandingan', '.'], ['inilah', 'guna', 'dan', 'arti', 'penting', 'sebuah', 'tim', ',', 'yang', 'mana', 'pemainnya', 'mampu', 'saling', 'berkontribusi', 'untuk', 'membantu', 'tim', 'memenangkan', 'pertandingan', ',', '”', 'kata', 'defoe', '.']]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [['liputan6', '.', 'com', ',', 'jakarta', ':', 'harga', 'sejumlah', 'kebutuhan', 'pokok', 'di', 'berbagai', 'daerah', 'mengalami', 'kenaikan', 'dalam', 'sepekan', 'terakhir', '.'], ['di', 'pasar', 'mampang', 'dan', 'pasar', 'tebet', ',', 'jakarta', 'selatan', ',', 'misalnya', ',', 'hanya', 'komoditas', 'beras', 'yang', 'tidak', 'mengalami', 'kenaikan', '.'], ['sedangkan', 'minyak', 'goreng', 'dan', 'telur', 'mengalami', 'kenaikan', 'yang', 'paling', 'tinggi', 'dalam', 'dua', 'hari', 'ini', ',', 'yaitu', 'mencapai', 'rp', '2', '.', '000', 'per', 'kilogram', '.'], ['kebutuhan', 'pokok', 'lainnya', 'seperti', 'gula', ',', 'susu', ',', 'dan', 'sayur-sayuran', 'mengalami', 'kenaikan', 'rp', '500', 'per', 'kilogramnya', '.'], ['sementara', 'di', 'kota', 'ambon', ',', 'maluku', ',', 'harga', 'minyak', 'goreng', 'di', 'sejumlah', 'pasar', 'tradisional', 'dalam', 'tiga', 'hari', 'terakhir', 'merangkak', 'naik', 'mencapai', 'rp', '3', '.', '000', 'per', 'kilogram', '.'], ['kini', ',', 'warga', 'harus', 'membeli', 'satu', 'kilogram', 'minyak', 'goreng', 'seharga', 'rp', '12', 'ribu', '.'], ['menurut', 'para', 'pedagang', ',', 'kenaikan', 'harga', 'disebabkan', 'langkanya', 'pasokan', 'minyak', 'goreng', 'ke', 'wilayah', 'ambon', '.'], ['sedangkan', 'di', 'majene', ',', 'sulawesi', 'barat', ',', 'menjelang', 'ramadan', 'ini', 'harga', 'sembako', 'di', 'pasar', 'tradisional', 'juga', 'melonjak', 'naik', '.'], ['lonjakan', 'harga', 'paling', 'tinggi', 'terjadi', 'pada', 'terigu', 'ukuran', '25', 'kilogram', 'yang', 'naik', 'rp', '13', 'ribu', 'setiap', 'karung', '.'], ['kenaikan', 'juga', 'terjadi', 'pada', 'harga', 'telur', 'yang', 'mencapai', 'rp', '150', 'untuk', 'satu', 'butir', '.'], ['daerah', 'lain', 'yang', 'juga', 'mengalami', 'kenaikan', 'sejumlah', 'bahan', 'pokok', 'adalah', 'karawang', ',', 'jabar', ',', 'dan', 'serang', ',', 'banten', '.'], ['diperkirakan', ',', 'lonjakan', 'harga', 'akan', 'terus', 'terjadi', 'hingga', 'menjelang', 'lebaran', 'mendatang', '[', 'baca', ':', 'harga-harga', 'terus', 'merangkak', 'naik', ']', '.', '(', 'ado/tim', 'liputan', '6', 'sctv', ')', '.']]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [['liputan6', ',', 'com', ',', 'kupang', ':', 'evakuasi', 'warga', 'negara', 'indonesia', 'dari', 'timor', 'leste', 'dengan', 'dua', 'hercules', 'tni', 'angkatan', 'udara', 'berakhir', ',', 'selasa', '(', '30/5', ')', '.'], ['dalam', 'empat', 'hari', 'ini', ',', '1', '.', '540', 'wni', 'telah', 'diangkut', 'keluar', 'dari', 'timor', 'leste', 'melalui', 'udara', '.'], ['sekitar', 'lima', 'ratus', 'wni', 'meninggalkan', 'dili', 'lewat', 'jalur', 'darat', '.', 'dari', 'kurang', 'lebih', '3', '.', '000', 'orang', ',', 'masih', 'tersisa', 'sekitar', '1', '.', '000', 'warga', 'indonesia', 'yang', 'belum', 'dievakuasi', '.'], ['sebagian', 'dari', 'mereka', 'masih', 'berharap', 'kondisi', 'keamanan', 'timor', 'leste', 'segera', 'pulih', '[', 'baca', ':', 'wni', 'keluar', 'dili', 'dalam', 'kondisi', 'stres', ']', '.'], ['sebagian', 'lain', 'tidak', 'diketahui', 'keberadaannya', 'hingga', 'sulit', 'dievakuasi', '.'], ['tni', 'au', 'masih', 'menyiagakan', 'dua', 'pesawat', 'hercules', 'di', 'kupang', ',', 'nusatenggara', 'timur', ',', 'untuk', 'mengangkut', 'wni', 'yang', 'tersisa', '.'], ['suasana', 'kota', 'dili', 'masih', 'mencekam', '.'], ['penjarahan', 'dan', 'pembakaran', 'rumah', 'terjadi', 'di', 'berbagai', 'sudut', 'kota', '.'], ['pertentangan', 'antara', 'kelompok', 'warga', 'yang', 'dari', 'wilayah', 'barat', 'atau', 'loromanu', 'dengan', 'warga', 'dari', 'wilayah', 'timur', 'atau', 'lorosae', 'makin', 'runcing', '.'], ['sebagian', 'pasukan', 'pemerintah', 'timor', 'leste', 'yang', 'berasal', 'dari', 'wilayah', 'bagian', 'timur', 'turut', 'memperkeruh', 'suasana', '.'], ['pasukan', 'yang', 'masih', 'setia', 'terhadap', 'pemerintah', 'ini', 'mengintimidasi', 'warga', 'dili', 'yang', 'berasal', 'dari', 'wilayah', 'barat', '.'], ['kondisi', 'panas', 'ini', 'memicu', 'perbedaan', 'pendapat', 'antara', 'presiden', 'xanana', 'gusmao', 'dan', 'perdana', 'menteri', 'mari', 'alkatiri', '.'], ['gusmao', 'menginginkan', 'pelucutan', 'senjata', 'seluruh', 'polisi', 'dan', 'militer', 'dan', 'mempekerjakan', 'sekitar', '600', 'tentara', 'desertir', 'yang', 'memberontak', '.'], ['sedangkan', 'alkatiri', 'menghendaki', 'pelucutan', 'senjata', 'bagi', 'pasukan', 'pemberontak', 'saja', 'sebelum', 'kembali', 'bertugas', '.', '(', 'tna/tim', 'liputan', '6', 'sctv', ')', '.']]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [['liputan6', '.', 'com', ',', 'lembata', ':', 'pusat', 'vulkanologi', 'dan', 'mitigasi', 'bencana', 'geologi', 'bandung', 'menetapkan', 'status', 'gunung', 'batutara', 'di', 'kabupaten', 'lembata', ',', 'nusatenggara', 'timur', 'menjadi', 'siaga', 'tiga', ',', 'karena', 'lahar', 'panas', 'terus', 'keluar', 'dari', 'puncak', 'gunung', ',', 'sejak', '19', 'maret', 'silam', '.'], ['lahar', 'panas', 'juga', 'keluar', 'dari', 'bagian', 'sebelah', 'timur', 'kaki', 'gunung', 'batutara', '.'], ['lahar', 'tersebut', 'mengalir', 'ke', 'laut', '.', 'gunung', 'batutara', 'yang', 'tingginya', 'sekitar', '3', '.', '700', 'meter', 'dari', 'permukaan', 'laut', 'terletak', 'di', 'pulau', 'komba', 'yang', 'tak', 'berpenghuni', '.'], ['meski', 'begitu', ',', 'warga', 'empat', 'kecamatan', 'yang', 'menghuni', 'sebuah', 'pulau', 'sekitar', '50', 'kilometer', 'dari', 'pulau', 'komba', 'diminta', 'waspada', '.'], ['adapun', 'jarak', 'pusat', 'kota', 'lembata', ',', 'leholba', 'dari', 'gunung', 'batutara', 'sekitar', '100', 'kilometer', '.', '(', 'jum/tim', 'liputan', '6', 'sctv', ')', '.']]
#
#                                                                                                                                                                                                                                                                                                                                   summary
# 0                                                                   [['artis', 'muda', 'haykal', 'dan', 'putri', 'titan', 'akan', 'memasuki', 'dunia', 'perkuliahan', '.'], ['walau', 'hasil', 'ujian', 'belum', 'keluar', ',', 'haykal', 'dan', 'tian', 'mengaku', 'sudah', 'memiliki', 'universitas', 'favorit', 'masing-masing', '.']]
# 1  [['pertandingan', 'melawan', 'manchester', 'city', 'merupakan', 'partai', 'ke-120', 'jermain', 'defoe', 'bersama', 'tottenham', 'hotspur', '.'], ['meski', 'mendapat', 'lirikan', 'dari', 'manchester', 'united', 'dan', 'aston', 'villa', ',', 'defoe', 'bertekad', 'tetap', 'akan', 'merumput', 'di', 'white', 'hart', 'lane', '.']]
# 2                                 [['harga', 'bahan', 'pokok', 'seperti', 'minyak', 'goreng', ',', 'telur', ',', 'dan', 'terigu', 'di', 'beberapa', 'daerah', 'melonjak', 'naik', 'sejak', 'sepekan', 'terakhir', '.'], ['kenaikan', 'tersebut', 'diperkirakan', 'terus', 'terjadi', 'hingga', 'menjelang', 'lebaran', 'mendatang', '.']]
# 3          [['evakuasi', 'warga', 'negara', 'indonesia', 'dari', 'timor', 'leste', 'berakhir', 'hari', 'ini', '.'], ['sebanyak', '1', '.', '500', 'lebih', 'warga', 'dievakuasi', 'lewat', 'udara', ',', '500', 'orang', 'keluar', 'dari', 'dili', 'lewat', 'jalur', 'darat', ',', 'dan', 'seribu', 'orang', 'memilih', 'bertahan', '.']]
# 4                                                      [['status', 'gunung', 'batutara', 'ditetapkan', 'siaga', 'tiga', 'karena', 'lahar', 'panas', 'terus', 'mengalir', 'dari', 'puncaknya', 'sejak', 'pekan', 'silam', '.'], ['warga', 'yang', 'tinggal', 'sekitar', '50', 'kilometer', 'dari', 'batutara', 'diminta', 'waspada', '.']]

# %% [markdown]
# # Lemmatization using nlp_id

# %%
#! pip install nlp-id

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nlp_id.lemmatizer import Lemmatizer

lemmatizer = Lemmatizer()

def lemmatize_text(text):
  tokens = word_tokenize(text)
  lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
  return " ".join(lemmatized_tokens)

train_df['text'] = train_df['text'].apply(lemmatize_text)
train_df['summary'] = train_df['summary'].apply(lemmatize_text)

test_df['text'] = test_df['text'].apply(lemmatize_text)
test_df['summary'] = test_df['summary'].apply(lemmatize_text)

dev_df['text'] = dev_df['text'].apply(lemmatize_text)
dev_df['summary'] = dev_df['summary'].apply(lemmatize_text)

# %%
train_df.iloc[0]
# Out:
# id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     238168
# url                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     https://www.liputan6.com/news/read/238168/haykal-dan-putri-titian-siap-jadi-mahasiswa
# clean_article                 [['Liputan6', '.', 'com', ',', 'Jakarta', ':', 'Setelah', 'menjalani', 'Ujian', 'Nasional', ',', 'artis', 'muda', 'Haykal', 'Kamil', 'bersiap', 'kuliah', '.'], ['Adik', 'dari', 'Zaskia', 'Adya', 'Mecca', 'itu', 'mengaku', 'dirinya', 'sengaja', 'absen', 'dari', 'layar', 'kaca', 'beberapa', 'waktu', 'silam', 'demi', 'pendidikan', '.'], ['"', 'Sengaja', 'syuting-syuting', 'aku', 'pending', '(', 'tunda', ')', 'semuanya', 'selama', 'kurang', 'kurang', 'lebih', 'empat', 'bulanan', ',', '"', 'ucap', 'Haykal', 'kepada', 'tim', 'Kasak', 'Kusuk', 'SCTV', ',', 'Kamis', '(', '23/7', ')', '.'], ['Ia', 'ingin', 'mengambil', 'jurusan', 'Hubungan', 'Internasional', 'atau', 'Ilmu', 'Politik', 'di', 'Universitas', 'Indonesia', '.'], ['Senada', 'dengan', 'Haykal', ',', 'Putri', 'Titian', 'pun', 'akan', 'memasuki', 'dunia', 'baru', ',', 'perkuliahan', '.'], ['Perempuan', 'bernama', 'lengkap', 'Putri', 'Titian', 'Asih', 'itu', 'mengungkapkan', 'sempat', 'bingung', 'menentukan', 'jurusan', 'yang', 'akan', 'diambilnya', 'nanti', '.'], ['Namun', ',', 'setelah', 'dipikir', 'masak-masak', ',', 'Tiansapaan', 'akrab', 'Putri', 'Titianmemutuskan', 'mengambil', 'Desain', 'Komunikasi', 'Visual', 'di', 'Universitas', 'Trisakti', '.'], ['Tian', 'sempat', 'mengalami', 'dilema', '.'], ['Ia', 'mendapat', 'tekanan', 'dari', 'keluarga', 'untuk', 'mengubah', 'penampilannya', 'yang', 'tomboi', '.'], ['Namun', 'demi', 'menjaga', 'sikap', 'di', 'bangku', 'kuliah', ',', 'pemain', 'sinetron', 'Gara-Gara', 'Cinta', 'itu', 'rela', 'melakukannya', '.'], ['"', 'Mulai', 'sekarang', 'biasain', 'pakai', 'yang', 'formil-formil', 'aja', ',', 'yang', 'lebih', 'rapi', ',', '"', 'ucap', 'Tian', '.', '(', 'ANS', ')', '.']]
# clean_summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [['Artis', 'muda', 'Haykal', 'dan', 'Putri', 'Titan', 'akan', 'memasuki', 'dunia', 'perkuliahan', '.'], ['Walau', 'hasil', 'ujian', 'belum', 'keluar', ',', 'Haykal', 'dan', 'Tian', 'mengaku', 'sudah', 'memiliki', 'universitas', 'favorit', 'masing-masing', '.']]
# extractive_summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [0, 4]
# text                                                                                                                                                                                                                                                                                                                                                    liputan6       com       jakarta       telah   jalan   uji   nasional       artis   muda   haykal   kamil   siap   kuliah         adik   dari   zaskia   adya   mecca   itu   aku   diri   sengaja   absen   dari   layar   kaca   beberapa   waktu   silam   demi   didik             sengaja   syuting   aku   pending       tunda       semua   lama   kurang   kurang   lebih   empat   bulan           ucap   haykal   kepada   tim   kasak   kusuk   sctv       kamis       23 7             ia   ingin   ambil   jurus   hubung   internasional   atau   ilmu   politik   di   universitas   indonesia         nada   dengan   haykal       putri   titi   pun   akan   masuk   dunia   baru       kuliah         perempuan   nama   lengkap   putri   titi   asih   itu   ungkap   sempat   bingung   tentu   jurus   yang   akan   ambil   nanti         namun       telah   pikir   masak       tiansapaan   akrab   putri   titianmemutuskan   ambil   desain   komunikasi   visual   di   universitas   trisakti         tian   sempat   alam   dilema         ia   dapat   tekan   dari   keluarga   untuk   ubah   tampil   yang   tomboi         namun   demi   jaga   sikap   di   bangku   kuliah       main   sinetron   gara-gara   cinta   itu   rela   laku             mulai   sekarang   biasain   pakai   yang   formil-formil   aja       yang   lebih   rapi           ucap   tian           ans
# summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               artis   muda   haykal   dan   putri   titan   akan   masuk   dunia   kuliah         walau   hasil   uji   belum   keluar       haykal   dan   tian   aku   sudah   milik   universitas   favorit   masing-masing
# extractive_summary_text       [['Liputan6', '.', 'com', ',', 'Jakarta', ':', 'Setelah', 'menjalani', 'Ujian', 'Nasional', ',', 'artis', 'muda', 'Haykal', 'Kamil', 'bersiap', 'kuliah', '.'], ['Adik', 'dari', 'Zaskia', 'Adya', 'Mecca', 'itu', 'mengaku', 'dirinya', 'sengaja', 'absen', 'dari', 'layar', 'kaca', 'beberapa', 'waktu', 'silam', 'demi', 'pendidikan', '.'], ['"', 'Sengaja', 'syuting-syuting', 'aku', 'pending', '(', 'tunda', ')', 'semuanya', 'selama', 'kurang', 'kurang', 'lebih', 'empat', 'bulanan', ',', '"', 'ucap', 'Haykal', 'kepada', 'tim', 'Kasak', 'Kusuk', 'SCTV', ',', 'Kamis', '(', '23/7', ')', '.'], ['Ia', 'ingin', 'mengambil', 'jurusan', 'Hubungan', 'Internasional', 'atau', 'Ilmu', 'Politik', 'di', 'Universitas', 'Indonesia', '.'], ['Senada', 'dengan', 'Haykal', ',', 'Putri', 'Titian', 'pun', 'akan', 'memasuki', 'dunia', 'baru', ',', 'perkuliahan', '.'], ['Perempuan', 'bernama', 'lengkap', 'Putri', 'Titian', 'Asih', 'itu', 'mengungkapkan', 'sempat', 'bingung', 'menentukan', 'jurusan', 'yang', 'akan', 'diambilnya', 'nanti', '.'], ['Namun', ',', 'setelah', 'dipikir', 'masak-masak', ',', 'Tiansapaan', 'akrab', 'Putri', 'Titianmemutuskan', 'mengambil', 'Desain', 'Komunikasi', 'Visual', 'di', 'Universitas', 'Trisakti', '.'], ['Tian', 'sempat', 'mengalami', 'dilema', '.'], ['Ia', 'mendapat', 'tekanan', 'dari', 'keluarga', 'untuk', 'mengubah', 'penampilannya', 'yang', 'tomboi', '.'], ['Namun', 'demi', 'menjaga', 'sikap', 'di', 'bangku', 'kuliah', ',', 'pemain', 'sinetron', 'Gara-Gara', 'Cinta', 'itu', 'rela', 'melakukannya', '.'], ['"', 'Mulai', 'sekarang', 'biasain', 'pakai', 'yang', 'formil-formil', 'aja', ',', 'yang', 'lebih', 'rapi', ',', '"', 'ucap', 'Tian', '.', '(', 'ANS', ')', '.']]
# rebuilt_extractive_summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[['Liputan6', '., '], ['Ia', 'ingin', 'mengambil', 'jurusan', 'Hubungan', 'Internasional', 'atau', 'Ilmu', 'Politik', 'di', 'Universitas', 'Indonesia', '.]
# Name: 0, dtype: object

# %%
train_df.head(1)
# Out:
#        id  \
# 0  238168
#
#                                                                                      url  \
# 0  https://www.liputan6.com/news/read/238168/haykal-dan-putri-titian-siap-jadi-mahasiswa
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      clean_article  \
# 0  [['Liputan6', '.', 'com', ',', 'Jakarta', ':', 'Setelah', 'menjalani', 'Ujian', 'Nasional', ',', 'artis', 'muda', 'Haykal', 'Kamil', 'bersiap', 'kuliah', '.'], ['Adik', 'dari', 'Zaskia', 'Adya', 'Mecca', 'itu', 'mengaku', 'dirinya', 'sengaja', 'absen', 'dari', 'layar', 'kaca', 'beberapa', 'waktu', 'silam', 'demi', 'pendidikan', '.'], ['"', 'Sengaja', 'syuting-syuting', 'aku', 'pending', '(', 'tunda', ')', 'semuanya', 'selama', 'kurang', 'kurang', 'lebih', 'empat', 'bulanan', ',', '"', 'ucap', 'Haykal', 'kepada', 'tim', 'Kasak', 'Kusuk', 'SCTV', ',', 'Kamis', '(', '23/7', ')', '.'], ['Ia', 'ingin', 'mengambil', 'jurusan', 'Hubungan', 'Internasional', 'atau', 'Ilmu', 'Politik', 'di', 'Universitas', 'Indonesia', '.'], ['Senada', 'dengan', 'Haykal', ',', 'Putri', 'Titian', 'pun', 'akan', 'memasuki', 'dunia', 'baru', ',', 'perkuliahan', '.'], ['Perempuan', 'bernama', 'lengkap', 'Putri', 'Titian', 'Asih', 'itu', 'mengungkapkan', 'sempat', 'bingung', 'menentukan', 'jurusan', 'yang', 'akan', 'diambilnya', 'nanti', '.'], ['Namun', ',', 'setelah', 'dipikir', 'masak-masak', ',', 'Tiansapaan', 'akrab', 'Putri', 'Titianmemutuskan', 'mengambil', 'Desain', 'Komunikasi', 'Visual', 'di', 'Universitas', 'Trisakti', '.'], ['Tian', 'sempat', 'mengalami', 'dilema', '.'], ['Ia', 'mendapat', 'tekanan', 'dari', 'keluarga', 'untuk', 'mengubah', 'penampilannya', 'yang', 'tomboi', '.'], ['Namun', 'demi', 'menjaga', 'sikap', 'di', 'bangku', 'kuliah', ',', 'pemain', 'sinetron', 'Gara-Gara', 'Cinta', 'itu', 'rela', 'melakukannya', '.'], ['"', 'Mulai', 'sekarang', 'biasain', 'pakai', 'yang', 'formil-formil', 'aja', ',', 'yang', 'lebih', 'rapi', ',', '"', 'ucap', 'Tian', '.', '(', 'ANS', ')', '.']]
#
#                                                                                                                                                                                                                                                            clean_summary  \
# 0  [['Artis', 'muda', 'Haykal', 'dan', 'Putri', 'Titan', 'akan', 'memasuki', 'dunia', 'perkuliahan', '.'], ['Walau', 'hasil', 'ujian', 'belum', 'keluar', ',', 'Haykal', 'dan', 'Tian', 'mengaku', 'sudah', 'memiliki', 'universitas', 'favorit', 'masing-masing', '.']]
#
#   extractive_summary  \
# 0             [0, 4]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text  \
# 0    liputan6       com       jakarta       telah   jalan   uji   nasional       artis   muda   haykal   kamil   siap   kuliah         adik   dari   zaskia   adya   mecca   itu   aku   diri   sengaja   absen   dari   layar   kaca   beberapa   waktu   silam   demi   didik             sengaja   syuting   aku   pending       tunda       semua   lama   kurang   kurang   lebih   empat   bulan           ucap   haykal   kepada   tim   kasak   kusuk   sctv       kamis       23 7             ia   ingin   ambil   jurus   hubung   internasional   atau   ilmu   politik   di   universitas   indonesia         nada   dengan   haykal       putri   titi   pun   akan   masuk   dunia   baru       kuliah         perempuan   nama   lengkap   putri   titi   asih   itu   ungkap   sempat   bingung   tentu   jurus   yang   akan   ambil   nanti         namun       telah   pikir   masak       tiansapaan   akrab   putri   titianmemutuskan   ambil   desain   komunikasi   visual   di   universitas   trisakti         tian   sempat   alam   dilema         ia   dapat   tekan   dari   keluarga   untuk   ubah   tampil   yang   tomboi         namun   demi   jaga   sikap   di   bangku   kuliah       main   sinetron   gara-gara   cinta   itu   rela   laku             mulai   sekarang   biasain   pakai   yang   formil-formil   aja       yang   lebih   rapi           ucap   tian           ans
#
#                                                                                                                                                                                                                      summary
# 0    artis   muda   haykal   dan   putri   titan   akan   masuk   dunia   kuliah         walau   hasil   uji   belum   keluar       haykal   dan   tian   aku   sudah   milik   universitas   favorit   masing-masing

# %%
import ast

# Function to safely convert string representation of list to an actual list of integers
def convert_to_integer_list(column_data):
    if isinstance(column_data, str):
        try:
            # Convert string to list
            result = ast.literal_eval(column_data)
            # Ensure all items are integers
            if all(isinstance(i, int) for i in result):
                return result
            else:
                return []  # Return empty if not all integers
        except (ValueError, SyntaxError):
            return []  # Return empty list if conversion fails
    elif isinstance(column_data, list) and all(isinstance(i, int) for i in column_data):
        return column_data  # Return as is if already a list of integers
    return []  # Return empty if conditions not met

# Apply conversion to the extractive_summary column
train_df['extractive_summary'] = train_df['extractive_summary'].apply(convert_to_integer_list)

# Now we can define the function to rebuild the extractive summary
def rebuild_extractive_summary(clean_article, extractive_summary):
    # Ensure clean_article is a list of lists
    if not isinstance(clean_article, list) or not all(isinstance(sent, list) for sent in clean_article):
        raise ValueError("clean_article should be a list of lists")

    # Ensure extractive_summary contains valid indices
    if not isinstance(extractive_summary, list) or not all(isinstance(idx, int) for idx in extractive_summary):
        raise ValueError("extractive_summary should be a list of integers")

    # Extract sentences based on the indices in extractive_summary
    extracted_sentences = [clean_article[idx] for idx in extractive_summary if idx < len(clean_article)]
    return extracted_sentences

# Apply the function to the entire dataframe
train_df['rebuilt_extractive_summary'] = train_df.apply(
    lambda row: rebuild_extractive_summary(row['clean_article'], row['extractive_summary']),
    axis=1
)

# Display the dataframe to verify the result
print(train_df[['id', 'rebuilt_extractive_summary']].head())
# Out:
#        id  \
# 0  238168
# 1  205215
# 2  146657
# 3  123694
# 4  139266
#
#                                                                                                                                                                                                                                                                                                                    rebuilt_extractive_summary
# 0                                                                                                                [[Liputan6, ., com, ,, Jakarta, :, Setelah, menjalani, Ujian, Nasional, ,, artis, muda, Haykal, Kamil, bersiap, kuliah, .], [Senada, dengan, Haykal, ,, Putri, Titian, pun, akan, memasuki, dunia, baru, ,, perkuliahan, .]]
# 1                                 [[Striker, Timnas, Inggris, yang, bermain, bersama, Tottenham, Hotspur, ,, Jermain, Defoe, disebut-sebut, sebagai, salah, satu, talenta, terbaik, yang, pernah, dimiliki, The, Three, Lions, .], [Defoe, pun, semakin, yakin, keputusannya, untuk, tetap, di, White, Hart, Lane, adalah, pilihan, jitu, .]]
# 2  [[Liputan6, ., com, ,, Jakarta, :, Harga, sejumlah, kebutuhan, pokok, di, berbagai, daerah, mengalami, kenaikan, dalam, sepekan, terakhir, .], [Diperkirakan, ,, lonjakan, harga, akan, terus, terjadi, hingga, menjelang, Lebaran, mendatang, [, baca, :, Harga-Harga, Terus, Merangkak, Naik, ], ., (, ADO/Tim, Liputan, 6, SCTV, ), .]]
# 3                         [[Dalam, empat, hari, ini, ,, 1, ., 540, WNI, telah, diangkut, keluar, dari, Timor, Leste, melalui, udara, .], [Sekitar, lima, ratus, WNI, meninggalkan, Dili, lewat, jalur, darat, ., Dari, kurang, lebih, 3, ., 000, orang, ,, masih, tersisa, sekitar, 1, ., 000, warga, Indonesia, yang, belum, dievakuasi, .]]
# 4                                                                                                        [[Lahar, panas, juga, keluar, dari, bagian, sebelah, timur, kaki, Gunung, Batutara, .], [Meski, begitu, ,, warga, empat, kecamatan, yang, menghuni, sebuah, pulau, sekitar, 50, kilometer, dari, Pulau, Komba, diminta, waspada, .]]

# %%
train_df.head(1)
# Out:
#        id  \
# 0  238168
#
#                                                                                      url  \
# 0  https://www.liputan6.com/news/read/238168/haykal-dan-putri-titian-siap-jadi-mahasiswa
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          clean_article  \
# 0  [[Liputan6, ., com, ,, Jakarta, :, Setelah, menjalani, Ujian, Nasional, ,, artis, muda, Haykal, Kamil, bersiap, kuliah, .], [Adik, dari, Zaskia, Adya, Mecca, itu, mengaku, dirinya, sengaja, absen, dari, layar, kaca, beberapa, waktu, silam, demi, pendidikan, .], [", Sengaja, syuting-syuting, aku, pending, (, tunda, ), semuanya, selama, kurang, kurang, lebih, empat, bulanan, ,, ", ucap, Haykal, kepada, tim, Kasak, Kusuk, SCTV, ,, Kamis, (, 23/7, ), .], [Ia, ingin, mengambil, jurusan, Hubungan, Internasional, atau, Ilmu, Politik, di, Universitas, Indonesia, .], [Senada, dengan, Haykal, ,, Putri, Titian, pun, akan, memasuki, dunia, baru, ,, perkuliahan, .], [Perempuan, bernama, lengkap, Putri, Titian, Asih, itu, mengungkapkan, sempat, bingung, menentukan, jurusan, yang, akan, diambilnya, nanti, .], [Namun, ,, setelah, dipikir, masak-masak, ,, Tiansapaan, akrab, Putri, Titianmemutuskan, mengambil, Desain, Komunikasi, Visual, di, Universitas, Trisakti, .], [Tian, sempat, mengalami, dilema, .], [Ia, mendapat, tekanan, dari, keluarga, untuk, mengubah, penampilannya, yang, tomboi, .], [Namun, demi, menjaga, sikap, di, bangku, kuliah, ,, pemain, sinetron, Gara-Gara, Cinta, itu, rela, melakukannya, .], [", Mulai, sekarang, biasain, pakai, yang, formil-formil, aja, ,, yang, lebih, rapi, ,, ", ucap, Tian, ., (, ANS, ), .]]
#
#                                                                                                                                                                                                                                                            clean_summary  \
# 0  [['Artis', 'muda', 'Haykal', 'dan', 'Putri', 'Titan', 'akan', 'memasuki', 'dunia', 'perkuliahan', '.'], ['Walau', 'hasil', 'ujian', 'belum', 'keluar', ',', 'Haykal', 'dan', 'Tian', 'mengaku', 'sudah', 'memiliki', 'universitas', 'favorit', 'masing-masing', '.']]
#
#   extractive_summary  \
# 0             [0, 4]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text  \
# 0    liputan6       com       jakarta       telah   jalan   uji   nasional       artis   muda   haykal   kamil   siap   kuliah         adik   dari   zaskia   adya   mecca   itu   aku   diri   sengaja   absen   dari   layar   kaca   beberapa   waktu   silam   demi   didik             sengaja   syuting   aku   pending       tunda       semua   lama   kurang   kurang   lebih   empat   bulan           ucap   haykal   kepada   tim   kasak   kusuk   sctv       kamis       23 7             ia   ingin   ambil   jurus   hubung   internasional   atau   ilmu   politik   di   universitas   indonesia         nada   dengan   haykal       putri   titi   pun   akan   masuk   dunia   baru       kuliah         perempuan   nama   lengkap   putri   titi   asih   itu   ungkap   sempat   bingung   tentu   jurus   yang   akan   ambil   nanti         namun       telah   pikir   masak       tiansapaan   akrab   putri   titianmemutuskan   ambil   desain   komunikasi   visual   di   universitas   trisakti         tian   sempat   alam   dilema         ia   dapat   tekan   dari   keluarga   untuk   ubah   tampil   yang   tomboi         namun   demi   jaga   sikap   di   bangku   kuliah       main   sinetron   gara-gara   cinta   itu   rela   laku             mulai   sekarang   biasain   pakai   yang   formil-formil   aja       yang   lebih   rapi           ucap   tian           ans
#
#                                                                                                                                                                                                                      summary  \
# 0    artis   muda   haykal   dan   putri   titan   akan   masuk   dunia   kuliah         walau   hasil   uji   belum   keluar       haykal   dan   tian   aku   sudah   milik   universitas   favorit   masing-masing
#
#                                                                                                                                                                                                      rebuilt_extractive_summary
# 0  [[Liputan6, ., com, ,, Jakarta, :, Setelah, menjalani, Ujian, Nasional, ,, artis, muda, Haykal, Kamil, bersiap, kuliah, .], [Senada, dengan, Haykal, ,, Putri, Titian, pun, akan, memasuki, dunia, baru, ,, perkuliahan, .]]

# %%
# move the column "rebuilt_extractive_summary" to be placed after the column "extractive_summary" in the dataset

# Get the column names
cols = list(train_df.columns)

# Find the index of 'extractive_summary'
extractive_summary_index = cols.index('extractive_summary')

# Insert 'rebuilt_extractive_summary' after 'extractive_summary'
try:
  rebuilt_extractive_summary_index = cols.index('rebuilt_extractive_summary')
  cols.insert(extractive_summary_index + 1, cols.pop(rebuilt_extractive_summary_index))
except ValueError:
  pass  # Handle the case where 'rebuilt_extractive_summary' is not found


# Reorder the dataframe columns
train_df = train_df[cols]

# Print the updated dataframe
train_df.head(1)
# Out:
#        id  \
# 0  238168
#
#                                                                                      url  \
# 0  https://www.liputan6.com/news/read/238168/haykal-dan-putri-titian-siap-jadi-mahasiswa
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          clean_article  \
# 0  [[Liputan6, ., com, ,, Jakarta, :, Setelah, menjalani, Ujian, Nasional, ,, artis, muda, Haykal, Kamil, bersiap, kuliah, .], [Adik, dari, Zaskia, Adya, Mecca, itu, mengaku, dirinya, sengaja, absen, dari, layar, kaca, beberapa, waktu, silam, demi, pendidikan, .], [", Sengaja, syuting-syuting, aku, pending, (, tunda, ), semuanya, selama, kurang, kurang, lebih, empat, bulanan, ,, ", ucap, Haykal, kepada, tim, Kasak, Kusuk, SCTV, ,, Kamis, (, 23/7, ), .], [Ia, ingin, mengambil, jurusan, Hubungan, Internasional, atau, Ilmu, Politik, di, Universitas, Indonesia, .], [Senada, dengan, Haykal, ,, Putri, Titian, pun, akan, memasuki, dunia, baru, ,, perkuliahan, .], [Perempuan, bernama, lengkap, Putri, Titian, Asih, itu, mengungkapkan, sempat, bingung, menentukan, jurusan, yang, akan, diambilnya, nanti, .], [Namun, ,, setelah, dipikir, masak-masak, ,, Tiansapaan, akrab, Putri, Titianmemutuskan, mengambil, Desain, Komunikasi, Visual, di, Universitas, Trisakti, .], [Tian, sempat, mengalami, dilema, .], [Ia, mendapat, tekanan, dari, keluarga, untuk, mengubah, penampilannya, yang, tomboi, .], [Namun, demi, menjaga, sikap, di, bangku, kuliah, ,, pemain, sinetron, Gara-Gara, Cinta, itu, rela, melakukannya, .], [", Mulai, sekarang, biasain, pakai, yang, formil-formil, aja, ,, yang, lebih, rapi, ,, ", ucap, Tian, ., (, ANS, ), .]]
#
#                                                                                                                                                                                                                                                            clean_summary  \
# 0  [['Artis', 'muda', 'Haykal', 'dan', 'Putri', 'Titan', 'akan', 'memasuki', 'dunia', 'perkuliahan', '.'], ['Walau', 'hasil', 'ujian', 'belum', 'keluar', ',', 'Haykal', 'dan', 'Tian', 'mengaku', 'sudah', 'memiliki', 'universitas', 'favorit', 'masing-masing', '.']]
#
#   extractive_summary  \
# 0             [0, 4]
#
#                                                                                                                                                                                                      rebuilt_extractive_summary  \
# 0  [[Liputan6, ., com, ,, Jakarta, :, Setelah, menjalani, Ujian, Nasional, ,, artis, muda, Haykal, Kamil, bersiap, kuliah, .], [Senada, dengan, Haykal, ,, Putri, Titian, pun, akan, memasuki, dunia, baru, ,, perkuliahan, .]]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text  \
# 0    liputan6       com       jakarta       telah   jalan   uji   nasional       artis   muda   haykal   kamil   siap   kuliah         adik   dari   zaskia   adya   mecca   itu   aku   diri   sengaja   absen   dari   layar   kaca   beberapa   waktu   silam   demi   didik             sengaja   syuting   aku   pending       tunda       semua   lama   kurang   kurang   lebih   empat   bulan           ucap   haykal   kepada   tim   kasak   kusuk   sctv       kamis       23 7             ia   ingin   ambil   jurus   hubung   internasional   atau   ilmu   politik   di   universitas   indonesia         nada   dengan   haykal       putri   titi   pun   akan   masuk   dunia   baru       kuliah         perempuan   nama   lengkap   putri   titi   asih   itu   ungkap   sempat   bingung   tentu   jurus   yang   akan   ambil   nanti         namun       telah   pikir   masak       tiansapaan   akrab   putri   titianmemutuskan   ambil   desain   komunikasi   visual   di   universitas   trisakti         tian   sempat   alam   dilema         ia   dapat   tekan   dari   keluarga   untuk   ubah   tampil   yang   tomboi         namun   demi   jaga   sikap   di   bangku   kuliah       main   sinetron   gara-gara   cinta   itu   rela   laku             mulai   sekarang   biasain   pakai   yang   formil-formil   aja       yang   lebih   rapi           ucap   tian           ans
#
#                                                                                                                                                                                                                      summary
# 0    artis   muda   haykal   dan   putri   titan   akan   masuk   dunia   kuliah         walau   hasil   uji   belum   keluar       haykal   dan   tian   aku   sudah   milik   universitas   favorit   masing-masing

# %%
train_df.iloc[0]
# Out:
# id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             238168
# url                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             https://www.liputan6.com/news/read/238168/haykal-dan-putri-titian-siap-jadi-mahasiswa
# clean_article                                                                     [[Liputan6, ., com, ,, Jakarta, :, Setelah, menjalani, Ujian, Nasional, ,, artis, muda, Haykal, Kamil, bersiap, kuliah, .], [Adik, dari, Zaskia, Adya, Mecca, itu, mengaku, dirinya, sengaja, absen, dari, layar, kaca, beberapa, waktu, silam, demi, pendidikan, .], [", Sengaja, syuting-syuting, aku, pending, (, tunda, ), semuanya, selama, kurang, kurang, lebih, empat, bulanan, ,, ", ucap, Haykal, kepada, tim, Kasak, Kusuk, SCTV, ,, Kamis, (, 23/7, ), .], [Ia, ingin, mengambil, jurusan, Hubungan, Internasional, atau, Ilmu, Politik, di, Universitas, Indonesia, .], [Senada, dengan, Haykal, ,, Putri, Titian, pun, akan, memasuki, dunia, baru, ,, perkuliahan, .], [Perempuan, bernama, lengkap, Putri, Titian, Asih, itu, mengungkapkan, sempat, bingung, menentukan, jurusan, yang, akan, diambilnya, nanti, .], [Namun, ,, setelah, dipikir, masak-masak, ,, Tiansapaan, akrab, Putri, Titianmemutuskan, mengambil, Desain, Komunikasi, Visual, di, Universitas, Trisakti, .], [Tian, sempat, mengalami, dilema, .], [Ia, mendapat, tekanan, dari, keluarga, untuk, mengubah, penampilannya, yang, tomboi, .], [Namun, demi, menjaga, sikap, di, bangku, kuliah, ,, pemain, sinetron, Gara-Gara, Cinta, itu, rela, melakukannya, .], [", Mulai, sekarang, biasain, pakai, yang, formil-formil, aja, ,, yang, lebih, rapi, ,, ", ucap, Tian, ., (, ANS, ), .]]
# clean_summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [['Artis', 'muda', 'Haykal', 'dan', 'Putri', 'Titan', 'akan', 'memasuki', 'dunia', 'perkuliahan', '.'], ['Walau', 'hasil', 'ujian', 'belum', 'keluar', ',', 'Haykal', 'dan', 'Tian', 'mengaku', 'sudah', 'memiliki', 'universitas', 'favorit', 'masing-masing', '.']]
# extractive_summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [0, 4]
# rebuilt_extractive_summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[Liputan6, ., com, ,, Jakarta, :, Setelah, menjalani, Ujian, Nasional, ,, artis, muda, Haykal, Kamil, bersiap, kuliah, .], [Senada, dengan, Haykal, ,, Putri, Titian, pun, akan, memasuki, dunia, baru, ,, perkuliahan, .]]
# text                            liputan6       com       jakarta       telah   jalan   uji   nasional       artis   muda   haykal   kamil   siap   kuliah         adik   dari   zaskia   adya   mecca   itu   aku   diri   sengaja   absen   dari   layar   kaca   beberapa   waktu   silam   demi   didik             sengaja   syuting   aku   pending       tunda       semua   lama   kurang   kurang   lebih   empat   bulan           ucap   haykal   kepada   tim   kasak   kusuk   sctv       kamis       23 7             ia   ingin   ambil   jurus   hubung   internasional   atau   ilmu   politik   di   universitas   indonesia         nada   dengan   haykal       putri   titi   pun   akan   masuk   dunia   baru       kuliah         perempuan   nama   lengkap   putri   titi   asih   itu   ungkap   sempat   bingung   tentu   jurus   yang   akan   ambil   nanti         namun       telah   pikir   masak       tiansapaan   akrab   putri   titianmemutuskan   ambil   desain   komunikasi   visual   di   universitas   trisakti         tian   sempat   alam   dilema         ia   dapat   tekan   dari   keluarga   untuk   ubah   tampil   yang   tomboi         namun   demi   jaga   sikap   di   bangku   kuliah       main   sinetron   gara-gara   cinta   itu   rela   laku             mulai   sekarang   biasain   pakai   yang   formil-formil   aja       yang   lebih   rapi           ucap   tian           ans
# summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       artis   muda   haykal   dan   putri   titan   akan   masuk   dunia   kuliah         walau   hasil   uji   belum   keluar       haykal   dan   tian   aku   sudah   milik   universitas   favorit   masing-masing
# Name: 0, dtype: object

# %%
from nlp_id.lemmatizer import Lemmatizer
from nltk.tokenize import word_tokenize

lemmatizer = Lemmatizer()

def lemmatize_text(text):
  # Check if text is a list of lists (tokenized sentences)
  if isinstance(text, list) and all(isinstance(item, list) for item in text):
    # Flatten the list and join the tokens into a string
    flat_text = " ".join([" ".join(sublist) for sublist in text])
    tokens = word_tokenize(flat_text)
  else:
    # If text is already a string, tokenize directly
    tokens = word_tokenize(text)

  lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
  return " ".join(lemmatized_tokens)

# Apply the function to the 'rebuilt_extractive_summary' column
train_df['e_summary'] = train_df['rebuilt_extractive_summary'].apply(lemmatize_text)
# Out:
# <ipython-input-46-0a702ca7379c>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['e_summary'] = train_df['rebuilt_extractive_summary'].apply(lemmatize_text)

# %%
train_df.iloc[0]
# Out:
# id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             238168
# url                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             https://www.liputan6.com/news/read/238168/haykal-dan-putri-titian-siap-jadi-mahasiswa
# clean_article                                                                     [[Liputan6, ., com, ,, Jakarta, :, Setelah, menjalani, Ujian, Nasional, ,, artis, muda, Haykal, Kamil, bersiap, kuliah, .], [Adik, dari, Zaskia, Adya, Mecca, itu, mengaku, dirinya, sengaja, absen, dari, layar, kaca, beberapa, waktu, silam, demi, pendidikan, .], [", Sengaja, syuting-syuting, aku, pending, (, tunda, ), semuanya, selama, kurang, kurang, lebih, empat, bulanan, ,, ", ucap, Haykal, kepada, tim, Kasak, Kusuk, SCTV, ,, Kamis, (, 23/7, ), .], [Ia, ingin, mengambil, jurusan, Hubungan, Internasional, atau, Ilmu, Politik, di, Universitas, Indonesia, .], [Senada, dengan, Haykal, ,, Putri, Titian, pun, akan, memasuki, dunia, baru, ,, perkuliahan, .], [Perempuan, bernama, lengkap, Putri, Titian, Asih, itu, mengungkapkan, sempat, bingung, menentukan, jurusan, yang, akan, diambilnya, nanti, .], [Namun, ,, setelah, dipikir, masak-masak, ,, Tiansapaan, akrab, Putri, Titianmemutuskan, mengambil, Desain, Komunikasi, Visual, di, Universitas, Trisakti, .], [Tian, sempat, mengalami, dilema, .], [Ia, mendapat, tekanan, dari, keluarga, untuk, mengubah, penampilannya, yang, tomboi, .], [Namun, demi, menjaga, sikap, di, bangku, kuliah, ,, pemain, sinetron, Gara-Gara, Cinta, itu, rela, melakukannya, .], [", Mulai, sekarang, biasain, pakai, yang, formil-formil, aja, ,, yang, lebih, rapi, ,, ", ucap, Tian, ., (, ANS, ), .]]
# clean_summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [['Artis', 'muda', 'Haykal', 'dan', 'Putri', 'Titan', 'akan', 'memasuki', 'dunia', 'perkuliahan', '.'], ['Walau', 'hasil', 'ujian', 'belum', 'keluar', ',', 'Haykal', 'dan', 'Tian', 'mengaku', 'sudah', 'memiliki', 'universitas', 'favorit', 'masing-masing', '.']]
# extractive_summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [0, 4]
# rebuilt_extractive_summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[Liputan6, ., com, ,, Jakarta, :, Setelah, menjalani, Ujian, Nasional, ,, artis, muda, Haykal, Kamil, bersiap, kuliah, .], [Senada, dengan, Haykal, ,, Putri, Titian, pun, akan, memasuki, dunia, baru, ,, perkuliahan, .]]
# text                            liputan6       com       jakarta       telah   jalan   uji   nasional       artis   muda   haykal   kamil   siap   kuliah         adik   dari   zaskia   adya   mecca   itu   aku   diri   sengaja   absen   dari   layar   kaca   beberapa   waktu   silam   demi   didik             sengaja   syuting   aku   pending       tunda       semua   lama   kurang   kurang   lebih   empat   bulan           ucap   haykal   kepada   tim   kasak   kusuk   sctv       kamis       23 7             ia   ingin   ambil   jurus   hubung   internasional   atau   ilmu   politik   di   universitas   indonesia         nada   dengan   haykal       putri   titi   pun   akan   masuk   dunia   baru       kuliah         perempuan   nama   lengkap   putri   titi   asih   itu   ungkap   sempat   bingung   tentu   jurus   yang   akan   ambil   nanti         namun       telah   pikir   masak       tiansapaan   akrab   putri   titianmemutuskan   ambil   desain   komunikasi   visual   di   universitas   trisakti         tian   sempat   alam   dilema         ia   dapat   tekan   dari   keluarga   untuk   ubah   tampil   yang   tomboi         namun   demi   jaga   sikap   di   bangku   kuliah       main   sinetron   gara-gara   cinta   itu   rela   laku             mulai   sekarang   biasain   pakai   yang   formil-formil   aja       yang   lebih   rapi           ucap   tian           ans
# summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       artis   muda   haykal   dan   putri   titan   akan   masuk   dunia   kuliah         walau   hasil   uji   belum   keluar       haykal   dan   tian   aku   sudah   milik   universitas   favorit   masing-masing
# e_summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    liputan6  com  jakarta  telah jalan uji nasional  artis muda haykal kamil siap kuliah  nada dengan haykal  putri titi pun akan masuk dunia baru  kuliah
# Name: 0, dtype: object

# %% [markdown]
# # Normalization on extractive summary

# %%
# prompt: make a code to save the train_df, test_df, and dev_df into csv files so i can download it

train_df.to_csv('train_processed.csv', index=False)
test_df.to_csv('test_processed.csv', index=False)
dev_df.to_csv('dev_processed.csv', index=False)
